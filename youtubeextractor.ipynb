# %%
import requests
import re
import pandas as pd
import logging

# Set up logging to display status messages with timestamps.
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# Your YouTube Data API key and Channel ID for '@amitvarma'
API_KEY = "AIzaSyBgXqdHjowUANqtW6XRSJkzf7kbPD9ur5o"
CHANNEL_ID = "UCs8a-hjf6X4pa-O0orSoC8w"

def get_uploads_playlist_id(channel_id, api_key, session):
    """
    Retrieves the playlist ID of the 'uploads' playlist for the specified channel.
    """
    url = "https://www.googleapis.com/youtube/v3/channels"
    params = {
        "part": "contentDetails",
        "id": channel_id,
        "key": api_key
    }
    try:
        response = session.get(url, params=params)
        response.raise_for_status()
        data = response.json()
    except Exception as e:
        logging.error(f"Error retrieving uploads playlist ID: {e}")
        return None

    items = data.get("items")
    if items:
        return items[0]["contentDetails"]["relatedPlaylists"]["uploads"]
    return None

def get_videos_from_playlist(playlist_id, api_key, session):
    """
    Fetches all videos from the specified playlist (typically the 'uploads' playlist of a channel).
    """
    base_url = "https://www.googleapis.com/youtube/v3/playlistItems"
    videos = []
    next_page_token = None

    while True:
        params = {
            "part": "snippet",
            "playlistId": playlist_id,
            "maxResults": 50,
            "pageToken": next_page_token,
            "key": api_key
        }
        try:
            response = session.get(base_url, params=params)
            response.raise_for_status()
            data = response.json()
        except Exception as e:
            logging.error(f"Error retrieving videos: {e}")
            break

        for item in data.get("items", []):
            snippet = item.get("snippet", {})
            resource = snippet.get("resourceId", {})
            video_id = resource.get("videoId")
            if video_id:
                videos.append({
                    "title": snippet.get("title", ""),
                    "video_id": video_id,
                    "link": f"https://www.youtube.com/watch?v={video_id}"
                })

        next_page_token = data.get("nextPageToken")
        if not next_page_token:
            break

    return videos

def get_video_description(video_id, api_key, session):
    """
    Retrieves the description of a specific YouTube video.
    """
    url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "snippet",
        "id": video_id,
        "key": api_key
    }
    try:
        response = session.get(url, params=params)
        response.raise_for_status()
        data = response.json()
    except Exception as e:
        logging.error(f"Error retrieving description for video {video_id}: {e}")
        return ""
    
    items = data.get("items")
    if items:
        return items[0]["snippet"].get("description", "")
    return ""

def extract_resources(description):
    """
    Extracts resources and their links from the video description.
    """
    resources = []
    pattern = r"USEFUL RESOURCES:\s*(.*?)\s*(?:\n\n|\Z)"
    match = re.search(pattern, description, re.DOTALL)
    if match:
        resources_section = match.group(1)
        resource_pattern = r"\d+\.\s*(.*?)\s*:\s*(https?://\S+)"
        resources = re.findall(resource_pattern, resources_section)
    return resources

def main():
    with requests.Session() as session:
        logging.info("Retrieving uploads playlist ID...")
        playlist_id = get_uploads_playlist_id(CHANNEL_ID, API_KEY, session)
        if not playlist_id:
            logging.error("Failed to retrieve the uploads playlist ID.")
            return

        logging.info("Fetching videos from the playlist...")
        videos = get_videos_from_playlist(playlist_id, API_KEY, session)
        total_videos = len(videos)
        logging.info(f"Total number of videos found: {total_videos}")

        all_resources = []
        for index, video in enumerate(videos, start=1):
            logging.info(f"Processing video {index}/{total_videos}: {video['title']}")
            description = get_video_description(video["video_id"], API_KEY, session)
            resources = extract_resources(description)
            for title, link in resources:
                all_resources.append({
                    "video_title": video["title"],
                    "video_link": video["link"],
                    "resource_title": title,
                    "resource_link": link
                })

    # Create DataFrames for Excel output
    videos_df = pd.DataFrame(videos)
    resources_df = pd.DataFrame(all_resources)

    # Write DataFrames to an Excel file with multiple sheets.
    output_file = "YouTube_Channel_Data.xlsx"
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        videos_df.to_excel(writer, sheet_name="Video Links", index=False)
        resources_df.to_excel(writer, sheet_name="Resources", index=False)

    logging.info(f"Data has been successfully written to '{output_file}'.")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-07 15:25:18,811 - INFO - Retrieving uploads playlist ID...
# 2025-02-07 15:25:19,115 - INFO - Fetching videos from the playlist...
# 2025-02-07 15:25:21,553 - INFO - Total number of videos found: 85
# 2025-02-07 15:25:21,555 - INFO - Processing video 1/85: Underrated, Overrated, Complicated | Episode 85 | Everything is Everything
# 2025-02-07 15:25:21,670 - INFO - Processing video 2/85: The Age of Hybrid Warfare | Episode 84 | Everything is Everything
# 2025-02-07 15:25:21,789 - INFO - Processing video 3/85: The Atheism Episode | Episode 83 | Everything is Everything
# 2025-02-07 15:25:21,900 - INFO - Processing video 4/85: Invisible Infrastructure | Episode 82 | Everything is Everything
# 2025-02-07 15:25:22,013 - INFO - Processing video 5/85: Life Lessons From Chess in 2024 | Episode 81 | Everything is Everything
# 2025-02-07 15:25:22,146 - INFO - Processing video 6/85: Going Bankrupt in India | Episode 80 | Everything is Everything
# 2025-02-07 15:25:22,260 - INFO - Processing video 7/85: MORE Stories That Should be Films | Episode 79 | Everything is Everything
# 2025-02-07 15:25:22,375 - INFO - Processing video 8/85: The Case for Nuclear Electricity | Episode 78 | Everything is Everything
# 2025-02-07 15:25:22,493 - INFO - Processing video 9/85: Objects From Our Past | Episode 77 | Everything is Everything
# 2025-02-07 15:25:22,609 - INFO - Processing video 10/85: A History of Hinduism | Episode 76 | Everything is Everything
# 2025-02-07 15:25:22,729 - INFO - Processing video 11/85: What Economics Can Learn | Episode 75 | Everything is Everything
# 2025-02-07 15:25:22,845 - INFO - Processing video 12/85: The Horrors of KYC | Episode 74 | Everything is Everything
# 2025-02-07 15:25:22,969 - INFO - Processing video 13/85: Don't Punish Victimless Crimes | Episode 73 | Everything is Everything
# 2025-02-07 15:25:23,086 - INFO - Processing video 14/85: The Changing Forms of Creativity | Episode 72 | Everything is Everything
# 2025-02-07 15:25:23,203 - INFO - Processing video 15/85: The journey of Indian finance | Episode 71 | Everything is Everything
# 2025-02-07 15:25:23,321 - INFO - Processing video 16/85: How to Fix Competitive Exams | Episode 70 | Everything is Everything
# 2025-02-07 15:25:23,440 - INFO - Processing video 17/85: The Seven Basic Plots | Episode 69 | Everything is Everything
# 2025-02-07 15:25:23,563 - INFO - Processing video 18/85: Inflation Targeting Rocks!| Episode 68 | Everything is Everything
# 2025-02-07 15:25:23,682 - INFO - Processing video 19/85: Don't Mess With the Exchange Rate | Episode 67 | Everything is Everything
# 2025-02-07 15:25:23,802 - INFO - Processing video 20/85: Don't Mess With the Price System | Episode 66 | Everything is Everything
# 2025-02-07 15:25:23,917 - INFO - Processing video 21/85: Understanding India's Pensions Disaster | Episode 65 | Everything is Everything
# 2025-02-07 15:25:24,045 - INFO - Processing video 22/85: The Global Tech Wars | Episode 64 | Everything is Everything
# 2025-02-07 15:25:24,167 - INFO - Processing video 23/85: Knowledge Lost and Knowledge Regained | Episode 63 | Everything is Everything
# 2025-02-07 15:25:24,280 - INFO - Processing video 24/85: How to Write a Paper | Episode 62 | Everything is Everything
# 2025-02-07 15:25:24,403 - INFO - Processing video 25/85: The Outlaws | Episode 61 | Everything is Everything
# 2025-02-07 15:25:24,517 - INFO - Processing video 26/85: Don't Run a Country Like a Company | Episode 60 | Everything is Everything
# 2025-02-07 15:25:24,640 - INFO - Processing video 27/85: Rethinking Innovation Policy | Episode 59 | Everything is Everything
# 2025-02-07 15:25:24,831 - INFO - Processing video 28/85: Can We Build Switzerland in India?| Episode 58 | Everything is Everything
# 2025-02-07 15:25:24,951 - INFO - Processing video 29/85: How to Do Development| Episode 57 | Everything is Everything
# 2025-02-07 15:25:25,065 - INFO - Processing video 30/85: The Problem With Digital Public Goods | Episode 56 | Everything is Everything
# 2025-02-07 15:25:25,183 - INFO - Processing video 31/85: Where Has All the Infrastructure Gone? | Episode 55 | Everything is Everything
# 2025-02-07 15:25:25,296 - INFO - Processing video 32/85: A Deep Dive Into Education | Episode 54 | Everything is Everything
# 2025-02-07 15:25:25,414 - INFO - Processing video 33/85: A Passion for Cycling | Episode 53 | Everything is Everything
# 2025-02-07 15:25:25,539 - INFO - Processing video 34/85: The Life and Times of Chess | Episode 52 | Everything is Everything
# 2025-02-07 15:25:25,656 - INFO - Processing video 35/85: Lines on Maps Are Toxic! | Episode 51 | Everything is Everything
# 2025-02-07 15:25:25,770 - INFO - Processing video 36/85: Ask Me ANYTHING! | Episode 50 | Everything is Everything
# 2025-02-07 15:25:25,884 - INFO - Processing video 37/85: The Art of Podcasting | Episode 49 | Everything is Everything
# 2025-02-07 15:25:25,999 - INFO - Processing video 38/85: Graduating to Globalisation | Episode 48 | Everything is Everything
# 2025-02-07 15:25:26,114 - INFO - Processing video 39/85: India Needs Decentralization | Episode 47 | Everything is Everything
# 2025-02-07 15:25:26,229 - INFO - Processing video 40/85: Stay Away From Luxury Beliefs | Episode 46 | Everything is Everything
# 2025-02-07 15:25:26,352 - INFO - Processing video 41/85: Beware of These Five Fallacies! | Episode 45 | Everything is Everything
# 2025-02-07 15:25:26,465 - INFO - Processing video 42/85: Maps Are Magic | Episode 44 | Everything is Everything
# 2025-02-07 15:25:26,589 - INFO - Processing video 43/85: Six More Stories That Should Be Films | Episode 43 | Everything is Everything
# 2025-02-07 15:25:26,705 - INFO - Processing video 44/85: The Populist Playbook | Episode 42 | Everything is Everything
# 2025-02-07 15:25:26,819 - INFO - Processing video 45/85: Four Papers That Changed the World | Episode 41 | Everything is Everything
# 2025-02-07 15:25:26,940 - INFO - Processing video 46/85: The Brave New Future of Electricity | Episode 40 | Everything is Everything
# 2025-02-07 15:25:27,057 - INFO - Processing video 47/85: The Surface Area of Serendipity | Episode 39 | Everything is Everything
# 2025-02-07 15:25:27,174 - INFO - Processing video 48/85: Poker and Life | Episode 38 | Everything is Everything
# 2025-02-07 15:25:27,290 - INFO - Processing video 49/85: From Imperial to Adaptive Firms | Episode 37 | Everything is Everything
# 2025-02-07 15:25:27,408 - INFO - Processing video 50/85: The Long Road to Change | Episode 36 | Everything is Everything
# 2025-02-07 15:25:27,534 - INFO - Processing video 51/85: The Hiking Episode | Episode 35 | Everything is Everything
# 2025-02-07 15:25:27,646 - INFO - Processing video 52/85: How Family Firms Evolve | Episode 34 | Everything is Everything
# 2025-02-07 15:25:27,758 - INFO - Processing video 53/85: Public Choice Theory Explains SO MUCH | Episode 33 | Everything is Everything
# 2025-02-07 15:25:27,874 - INFO - Processing video 54/85: The UNIX Episode | Episode 32 | Everything is Everything
# 2025-02-07 15:25:27,999 - INFO - Processing video 55/85: A Deep Dive Into the Indian Military | Episode 31 | Everything is Everything
# 2025-02-07 15:25:28,119 - INFO - Processing video 56/85: Declutter | Episode 30 | Everything is Everything
# 2025-02-07 15:25:28,237 - INFO - Processing video 57/85: Five Epic Stories That Must Be Films | Episode 29 | Everything is Everything
# 2025-02-07 15:25:28,357 - INFO - Processing video 58/85: The Reformers | Episode 28 | Everything is Everything
# 2025-02-07 15:25:28,484 - INFO - Processing video 59/85: We Love Vaccines! We Love Freedom!  | Episode 27 | Everything is Everything
# 2025-02-07 15:25:28,593 - INFO - Processing video 60/85: When Should the State Act?  | Episode 26 | Everything is Everything
# 2025-02-07 15:25:28,709 - INFO - Processing video 61/85: Understanding the State | Episode 25 | Everything is Everything
# 2025-02-07 15:25:28,821 - INFO - Processing video 62/85: Fixing the Knowledge Society | Episode 24 | Everything is Everything
# 2025-02-07 15:25:28,939 - INFO - Processing video 63/85: Seven Stories That Should Be Films | Episode 23 | Everything is Everything
# 2025-02-07 15:25:29,055 - INFO - Processing video 64/85: Three Great Leaps by Firms | Episode 22 | Everything is Everything
# 2025-02-07 15:25:29,171 - INFO - Processing video 65/85: The Beauty of Finance | Episode 21 | Everything is Everything
# 2025-02-07 15:25:29,284 - INFO - Processing video 66/85: Our Population Is Our Greatest Asset | Episode 20 | Everything is Everything
# 2025-02-07 15:25:29,402 - INFO - Processing video 67/85: How to Think About Cricket (and Life) | Episode 19 | Everything is Everything
# 2025-02-07 15:25:29,520 - INFO - Processing video 68/85: What's Wrong With Indian Agriculture? | Episode 18 | Everything is Everything
# 2025-02-07 15:25:29,647 - INFO - Processing video 69/85: The Three Globalizations | Episode 17 | Everything is Everything
# 2025-02-07 15:25:29,771 - INFO - Processing video 70/85: The China Model is Broken | Episode 16 | Everything is Everything
# 2025-02-07 15:25:29,887 - INFO - Processing video 71/85: Math Is Better Than the Brigadier's Girlfriend | Episode 15 | Everything is Everything
# 2025-02-07 15:25:30,004 - INFO - Processing video 72/85: The State of the Ukraine War | Episode 14 | Everything is Everything
# 2025-02-07 15:25:30,128 - INFO - Processing video 73/85: What Bruce Springsteen Means to Us | Episode 13 | Everything is Everything
# 2025-02-07 15:25:30,243 - INFO - Processing video 74/85: Nothing is Indian! Everything is Indian! | Episode 12 | Everything is Everything
# 2025-02-07 15:25:30,362 - INFO - Processing video 75/85: The Greatest Productivity Mantra: Kaator Re Bhaaji! | Episode 11 | Everything is Everything
# 2025-02-07 15:25:30,478 - INFO - Processing video 76/85: Why Freedom Matters | Episode 10 | Everything is Everything
# 2025-02-07 15:25:30,594 - INFO - Processing video 77/85: How I Reversed My Type 2 Diabetes | Episode 9 | Everything is Everything
# 2025-02-07 15:25:30,710 - INFO - Processing video 78/85: Why Talent Comes in Clusters | Episode 8 | Everything is Everything
# 2025-02-07 15:25:30,825 - INFO - Processing video 79/85: Newton the Alchemist. Gandhi the Black Swan | Episode 7 | Everything is Everything
# 2025-02-07 15:25:30,943 - INFO - Processing video 80/85: The Incredible Insights of Bastiat and Hayek | Episode 6 | Everything is Everything
# 2025-02-07 15:25:31,065 - INFO - Processing video 81/85: My Hero, OPPENHEIMER | Episode 5 | Everything is Everything
# 2025-02-07 15:25:31,235 - INFO - Processing video 82/85: The WRONG Way to Fight Extremists | Episode 4 | Everything is Everything
# 2025-02-07 15:25:31,349 - INFO - Processing video 83/85: Are You Just One Version of Yourself?  | Episode 3 | Everything is Everything
# 2025-02-07 15:25:31,471 - INFO - Processing video 84/85: Is the Singularity Near? | Episode 2 | Everything is Everything
# 2025-02-07 15:25:31,587 - INFO - Processing video 85/85: Halfway From Coal, Halfway to Diamond | Episode 1 |  Everything is Everything
# 2025-02-07 15:25:32,138 - INFO - Data has been successfully written to 'YouTube_Channel_Data.xlsx'.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
#
# [notice] A new release of pip is available: 23.3.1 -> 25.0
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
